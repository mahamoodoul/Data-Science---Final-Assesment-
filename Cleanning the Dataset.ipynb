# %%
import pandas as pd #pd is the alias
import numpy as np 
import datetime
from os import listdir 
from os.path import isfile, join
import glob 
import re

# %%
df = pd.read_csv("data-set/Mahamud Shakil - free_session_information.csv")
df
# Out:
#             Time Stamp   Name of the candidate      Contact   \
# 0    8/24/2020 17:01:39  A.S.M. Raquibul Hasan   01722577922
# 1    8/24/2020 10:08:54                Abdullah          NaN
# 2     8/24/2020 9:20:28    Abdullah Bin Murad    01552443554
# 3    7/28/2020 12:16:30       Abhijoy Mukherjee   7003206060
# 4    7/10/2020 13:56:14     Abhipreeti Acharjee   8274839744
# ..                  ...                     ...          ...
# 963  1/22/2021 22:06:24       Ramanish Banerjee   8017179702
# 964  1/22/2021 22:46:21          Jinia Banerjee   6289719175
# 965  1/23/2021 10:57:08        Md Safiqul Islam   8250955315
# 966  1/23/2021 12:27:32     Soumojit Chatterjee   8101726672
# 967  1/23/2021 17:37:35  Debanjan Bhattacharjee   6290909245
#
#                                Email id   \
# 0                 raquibul.nsu@gmail.com
# 1              sharif3abdullah@gmail.com
# 2                   abmrifat54@gmail.com
# 3           abhijoymukherjee01@gmail.com
# ...

# %%
df.shape
# Out:
# (968, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 968 entries, 0 to 967
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Time Stamp               948 non-null    object
#  1   Name of the candidate    947 non-null    object
#  2   Contact                  909 non-null    object
#  3   Email id                 946 non-null    object
#  4   College name             940 non-null    object
#  5   Brach                    933 non-null    object
#  6   People having laptop     940 non-null    object
#  7   Souce of communication   432 non-null    object
#  8   Unnamed: 8               318 non-null    float64
#  9   Unnamed: 9               0 non-null      float64
#  10  Country                  476 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 83.3+ KB

# %%
#Handling Missing Data 
df.isna().sum()
# Out:
# Timestamp      20
# Name           21
# Contact        59
# Email          22
# College        28
# Department     35
# HasLaptop      28
# Source        536
# Country       492
# dtype: int64

# %% [markdown]
# # Dropping the Unnamed columns

# %%
df.drop(['Unnamed: 8', 'Unnamed: 9'], axis = 1, inplace = True)

# %%
df
# Out:
#             Time Stamp   Name of the candidate      Contact   \
# 0    8/24/2020 17:01:39  A.S.M. Raquibul Hasan   01722577922
# 1    8/24/2020 10:08:54                Abdullah          NaN
# 2     8/24/2020 9:20:28    Abdullah Bin Murad    01552443554
# 3    7/28/2020 12:16:30       Abhijoy Mukherjee   7003206060
# 4    7/10/2020 13:56:14     Abhipreeti Acharjee   8274839744
# ..                  ...                     ...          ...
# 963  1/22/2021 22:06:24       Ramanish Banerjee   8017179702
# 964  1/22/2021 22:46:21          Jinia Banerjee   6289719175
# 965  1/23/2021 10:57:08        Md Safiqul Islam   8250955315
# 966  1/23/2021 12:27:32     Soumojit Chatterjee   8101726672
# 967  1/23/2021 17:37:35  Debanjan Bhattacharjee   6290909245
#
#                                Email id   \
# 0                 raquibul.nsu@gmail.com
# 1              sharif3abdullah@gmail.com
# 2                   abmrifat54@gmail.com
# 3           abhijoymukherjee01@gmail.com
# ...

# %% [markdown]
# # Update the columns name

# %%
df.rename(columns={"Time Stamp ": "Timestamp", "Name of the candidate ": "Name","Contact ":"Contact","Email id ": "Email","College name ":"College","Brach ":"Department","People having laptop ":"HasLaptop","Souce of communication ":"Source","Country ":"Country"},inplace=True)

# %%
df.columns
# Out:
# Index(['Timestamp', 'Name', 'Contact', 'Email', 'College', 'Department',
#        'HasLaptop', 'Source', 'Country'],
#       dtype='object')

# %%
df
# Out:
#               Timestamp                    Name      Contact  \
# 0    8/24/2020 17:01:39  A.S.M. Raquibul Hasan   01722577922
# 1    8/24/2020 10:08:54                Abdullah          NaN
# 2     8/24/2020 9:20:28    Abdullah Bin Murad    01552443554
# 3    7/28/2020 12:16:30       Abhijoy Mukherjee   7003206060
# 4    7/10/2020 13:56:14     Abhipreeti Acharjee   8274839744
# ..                  ...                     ...          ...
# 963  1/22/2021 22:06:24       Ramanish Banerjee   8017179702
# 964  1/22/2021 22:46:21          Jinia Banerjee   6289719175
# 965  1/23/2021 10:57:08        Md Safiqul Islam   8250955315
# 966  1/23/2021 12:27:32     Soumojit Chatterjee   8101726672
# 967  1/23/2021 17:37:35  Debanjan Bhattacharjee   6290909245
#
#                                    Email  \
# 0                 raquibul.nsu@gmail.com
# 1              sharif3abdullah@gmail.com
# 2                   abmrifat54@gmail.com
# 3           abhijoymukherjee01@gmail.com
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 968 entries, 0 to 967
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Timestamp   948 non-null    object
#  1   Name        947 non-null    object
#  2   Contact     909 non-null    object
#  3   Email       946 non-null    object
#  4   College     940 non-null    object
#  5   Department  933 non-null    object
#  6   HasLaptop   940 non-null    object
#  7   Source      432 non-null    object
#  8   Country     476 non-null    object
# dtypes: object(9)
# memory usage: 68.2+ KB

# %% [markdown]
# # Saving the datset after removing unnecessary things

# %%
df.to_csv('free_session_information.csv')

# %% [markdown]
# # Batch information.csv dataset information

# %%
df2 = pd.read_csv("data-set/Mahamud Shakil - batch_inforamtion.csv")
df2
# Out:
#                    Time                  Email Address  \
# 0          8/1/20 23:05         deepanjan325@gmail.com
# 1          8/1/20 23:06     ranubanerjee1984@gmail.com
# 2          8/1/20 23:08         sharmisthaad@gmail.com
# 3          8/1/20 23:10          saikat20171@gmail.com
# 4          8/1/20 23:10       rahulroystat36@gmail.com
# ..                  ...                            ...
# 160  8/28/2020 12:15:37         souravkr2025@gmail.com
# 161  8/28/2020 20:45:00   srijani.adhikary13@gmail.com
# 162  8/28/2020 20:45:07         suvargha2000@gmail.com
# 163  8/28/2020 21:19:05         titutitasdey@gmail.com
# 164  8/28/2020 21:58:42  trishadutta25042001@gmail.com
#
#                         Name  \
# 0           Deepanjan Biswas
# 1              RANU BANERJEE
# 2        Sharmistha Adhikari
# 3               Saikat Mitra
# 4                  Rahul Roy
# ..                       ...
# 160         Sourav Kumar Dan
# 161         Srijani Adhikary
# ...

# %%
df2.shape
# Out:
# (165, 13)

# %%
df2.columns
# Out:
# Index([' Time', 'Email Address', 'Name',
#        'How well you guys are understanding the covered topics ?',
#        'Rate our way of training', 'How well your queries are getting solved ',
#        'Would you like to join our full time course ?',
#        'Would you like to recommend this course to others ?',
#        'Would you like to apply for paid internship programme by Softanbees  ?',
#        'Your suggestion for improving the training programme (Any other queries)',
#        'Please describe Here', 'Please describe here',
#        'Would you like to recommend this course to others ?.1'],
#       dtype='object')

# %%
df2[df2['Please describe Here'].isnull()]
# Out:
#                    Time                  Email Address  \
# 0          8/1/20 23:05         deepanjan325@gmail.com
# 2          8/1/20 23:08         sharmisthaad@gmail.com
# 3          8/1/20 23:10          saikat20171@gmail.com
# 4          8/1/20 23:10       rahulroystat36@gmail.com
# 5          8/1/20 23:10            as1973240@gmail.com
# ..                  ...                            ...
# 160  8/28/2020 12:15:37         souravkr2025@gmail.com
# 161  8/28/2020 20:45:00   srijani.adhikary13@gmail.com
# 162  8/28/2020 20:45:07         suvargha2000@gmail.com
# 163  8/28/2020 21:19:05         titutitasdey@gmail.com
# 164  8/28/2020 21:58:42  trishadutta25042001@gmail.com
#
#                         Name  \
# 0           Deepanjan Biswas
# 2        Sharmistha Adhikari
# 3               Saikat Mitra
# 4                  Rahul Roy
# 5             Abhishek Singh
# ..                       ...
# 160         Sourav Kumar Dan
# 161         Srijani Adhikary
# ...

# %%
df2[df2['Please describe here'].isnull()]
# Out:
#                    Time                  Email Address  \
# 0          8/1/20 23:05         deepanjan325@gmail.com
# 1          8/1/20 23:06     ranubanerjee1984@gmail.com
# 2          8/1/20 23:08         sharmisthaad@gmail.com
# 3          8/1/20 23:10          saikat20171@gmail.com
# 4          8/1/20 23:10       rahulroystat36@gmail.com
# ..                  ...                            ...
# 159   8/28/2020 8:22:27     sonalisarenmumpi@gmail.com
# 161  8/28/2020 20:45:00   srijani.adhikary13@gmail.com
# 162  8/28/2020 20:45:07         suvargha2000@gmail.com
# 163  8/28/2020 21:19:05         titutitasdey@gmail.com
# 164  8/28/2020 21:58:42  trishadutta25042001@gmail.com
#
#                         Name  \
# 0           Deepanjan Biswas
# 1              RANU BANERJEE
# 2        Sharmistha Adhikari
# 3               Saikat Mitra
# 4                  Rahul Roy
# ..                       ...
# 159             SONALI SAREN
# 161         Srijani Adhikary
# ...

# %% [markdown]
# |Please describe Here, Please describe Here| with this name has two columns and also from total 165 rows null values exits 131 rows and another one is full of null values. so this two columns will not be very necessary for us.

# %% [markdown]
# # Delete unnecessary column/column with irrelevant data/no data at all

# %%
df2.drop(['Please describe Here',], axis = 1, inplace = True)

# %%
df2.drop(['Please describe here',], axis = 1, inplace = True)

# %%
df2
# Out:
#                    Time                  Email Address  \
# 0          8/1/20 23:05         deepanjan325@gmail.com
# 1          8/1/20 23:06     ranubanerjee1984@gmail.com
# 2          8/1/20 23:08         sharmisthaad@gmail.com
# 3          8/1/20 23:10          saikat20171@gmail.com
# 4          8/1/20 23:10       rahulroystat36@gmail.com
# ..                  ...                            ...
# 160  8/28/2020 12:15:37         souravkr2025@gmail.com
# 161  8/28/2020 20:45:00   srijani.adhikary13@gmail.com
# 162  8/28/2020 20:45:07         suvargha2000@gmail.com
# 163  8/28/2020 21:19:05         titutitasdey@gmail.com
# 164  8/28/2020 21:58:42  trishadutta25042001@gmail.com
#
#                         Name  \
# 0           Deepanjan Biswas
# 1              RANU BANERJEE
# 2        Sharmistha Adhikari
# 3               Saikat Mitra
# 4                  Rahul Roy
# ..                       ...
# 160         Sourav Kumar Dan
# 161         Srijani Adhikary
# ...

# %% [markdown]
# # Update the columns name of Batch_information

# %%
df2.rename(columns={" Time": "Timestamp", "Email Address": "Email","How well you guys are understanding the covered topics ?": "UderstandingTopic(0-5)","Rate our way of training":"TrainingRating(0-5)","How well your queries are getting solved ":"Student_queries_sloved(0-5)","Would you like to join our full time course ?":"want_join_full_time_courses","Would you like to recommend this course to others ?":"recommend_course","Would you like to apply for paid internship programme by Softanbees  ?":"want_apply_paid_intership","Your suggestion for improving the training programme (Any other queries)":"suggestions_improving_program"},inplace=True)

# %%
df2.columns
# Out:
# Index(['Timestamp', 'Email', 'Name', 'UderstandingTopic(0-5)',
#        'TrainingRating(0-5)', 'Student_queries_sloved(0-5)',
#        'want_join_full_time_courses', 'recommend_course',
#        'want_apply_paid_intership', 'suggestions_improving_program',
#        'Would you like to recommend this course to others ?.1'],
#       dtype='object')

# %%
df2.head()
# Out:
#       Timestamp                       Email                 Name  \
# 0  8/1/20 23:05      deepanjan325@gmail.com     Deepanjan Biswas
# 1  8/1/20 23:06  ranubanerjee1984@gmail.com        RANU BANERJEE
# 2  8/1/20 23:08      sharmisthaad@gmail.com  Sharmistha Adhikari
# 3  8/1/20 23:10       saikat20171@gmail.com         Saikat Mitra
# 4  8/1/20 23:10    rahulroystat36@gmail.com            Rahul Roy
#
#    UderstandingTopic(0-5)  TrainingRating(0-5)  Student_queries_sloved(0-5)  \
# 0                     5.0                  5.0                          5.0
# 1                     5.0                  5.0                          5.0
# 2                     1.0                  1.0                          1.0
# 3                     4.0                  5.0                          5.0
# 4                     5.0                  5.0                          5.0
#
#   want_join_full_time_courses recommend_course want_apply_paid_intership  \
# ...

# %%
df2[df2['Would you like to recommend this course to others ?.1'].isnull()]
# Out:
#         Timestamp                       Email                 Name  \
# 0    8/1/20 23:05      deepanjan325@gmail.com     Deepanjan Biswas
# 1    8/1/20 23:06  ranubanerjee1984@gmail.com        RANU BANERJEE
# 2    8/1/20 23:08      sharmisthaad@gmail.com  Sharmistha Adhikari
# 3    8/1/20 23:10       saikat20171@gmail.com         Saikat Mitra
# 4    8/1/20 23:10    rahulroystat36@gmail.com            Rahul Roy
# ..            ...                         ...                  ...
# 64   8/4/20 11:01  anupriyahalder99@gmail.com      Anupriya Halder
# 65   8/4/20 12:32       sakshi90500@gmail.com        Kumari Sakshi
# 66   8/4/20 17:50   sharmagautam990@gmail.com  Gautam Kumar Sharma
# 67            NaN                         NaN                  NaN
# 125           NaN                         NaN                  NaN
#
#      UderstandingTopic(0-5)  TrainingRating(0-5)  Student_queries_sloved(0-5)  \
# 0                       5.0                  5.0                          5.0
# ...

# %%
df2[df2['recommend_course'].isnull()]
# Out:
#               Timestamp                          Email  \
# 67                  NaN                            NaN
# 68         8/5/20 22:50        snehaguha2017@gmail.com
# 69         8/5/20 22:53      mayuridharmegha@gmail.com
# 70         8/5/20 22:55           srijanim75@gmail.com
# 71         8/5/20 22:55  sanchitachowdhury02@gmail.com
# ..                  ...                            ...
# 160  8/28/2020 12:15:37         souravkr2025@gmail.com
# 161  8/28/2020 20:45:00   srijani.adhikary13@gmail.com
# 162  8/28/2020 20:45:07         suvargha2000@gmail.com
# 163  8/28/2020 21:19:05         titutitasdey@gmail.com
# 164  8/28/2020 21:58:42  trishadutta25042001@gmail.com
#
#                         Name  UderstandingTopic(0-5)  TrainingRating(0-5)  \
# 67                       NaN                     NaN                  NaN
# 68                Sneha Guha                     5.0                  5.0
# 69               Mayuri Dhar                     5.0                  5.0
# ...

# %%
#Handling Missing Data 
df2.isna().sum()
# Out:
# Timestamp                                                 2
# Email                                                     2
# Name                                                      2
# UderstandingTopic(0-5)                                    2
# TrainingRating(0-5)                                       2
# Student_queries_sloved(0-5)                               2
# want_join_full_time_courses                               2
# recommend_course                                         98
# want_apply_paid_intership                                 2
# suggestions_improving_program                            88
# Would you like to recommend this course to others ?.1    69
# dtype: int64

# %%
import math
def merge_recommend_columns(col1,col2):
    """
    if col2 value is NaN or null then the value will replace by the col1 value
    also if col1 value is not Nan
    """
    if col2 == "NaN" or col2 == " " and col1 != "NaN":
        col2 = col1
    return col2

# %%
df2['recommend1'] = df2.apply(lambda row : merge_recommend_columns(row['recommend_course'],row['Would you like to recommend this course to others ?.1']), axis = 1)

# %%
df2
# Out:
#               Timestamp                          Email  \
# 0          8/1/20 23:05         deepanjan325@gmail.com
# 1          8/1/20 23:06     ranubanerjee1984@gmail.com
# 2          8/1/20 23:08         sharmisthaad@gmail.com
# 3          8/1/20 23:10          saikat20171@gmail.com
# 4          8/1/20 23:10       rahulroystat36@gmail.com
# ..                  ...                            ...
# 160  8/28/2020 12:15:37         souravkr2025@gmail.com
# 161  8/28/2020 20:45:00   srijani.adhikary13@gmail.com
# 162  8/28/2020 20:45:07         suvargha2000@gmail.com
# 163  8/28/2020 21:19:05         titutitasdey@gmail.com
# 164  8/28/2020 21:58:42  trishadutta25042001@gmail.com
#
#                         Name  UderstandingTopic(0-5)  TrainingRating(0-5)  \
# 0           Deepanjan Biswas                     5.0                  5.0
# 1              RANU BANERJEE                     5.0                  5.0
# 2        Sharmistha Adhikari                     1.0                  1.0
# ...

# %%
#Handling Missing Data 
df2.isna().sum()
# Out:
# Timestamp                                                 2
# Email                                                     2
# Name                                                      2
# UderstandingTopic(0-5)                                    2
# TrainingRating(0-5)                                       2
# Student_queries_sloved(0-5)                               2
# want_join_full_time_courses                               2
# recommend_course                                         98
# want_apply_paid_intership                                 2
# suggestions_improving_program                            88
# Would you like to recommend this course to others ?.1    69
# recommend1                                               69
# dtype: int64

# %% [markdown]
# total recommend course null values 98 whereas  Would you like to recommend this course to others ?.1 also has 69 null values here build a function for this tow columns

# %%
help(merge_recommend_columns)
# Out:
# Help on function merge_recommend_columns in module __main__:
#
# merge_recommend_columns(col1, col2)
#     if col2 value is NaN or null then the value will replace by the col1 value
#     also if col1 value is not Nan

# %%
df2.drop(['Would you like to recommend this course to others ?.1',], axis = 1, inplace = True)
df2.drop(['recommend1',], axis = 1, inplace = True)

# %%
df2
# Out:
#               Timestamp                          Email  \
# 0          8/1/20 23:05         deepanjan325@gmail.com
# 1          8/1/20 23:06     ranubanerjee1984@gmail.com
# 2          8/1/20 23:08         sharmisthaad@gmail.com
# 3          8/1/20 23:10          saikat20171@gmail.com
# 4          8/1/20 23:10       rahulroystat36@gmail.com
# ..                  ...                            ...
# 160  8/28/2020 12:15:37         souravkr2025@gmail.com
# 161  8/28/2020 20:45:00   srijani.adhikary13@gmail.com
# 162  8/28/2020 20:45:07         suvargha2000@gmail.com
# 163  8/28/2020 21:19:05         titutitasdey@gmail.com
# 164  8/28/2020 21:58:42  trishadutta25042001@gmail.com
#
#                         Name  UderstandingTopic(0-5)  TrainingRating(0-5)  \
# 0           Deepanjan Biswas                     5.0                  5.0
# 1              RANU BANERJEE                     5.0                  5.0
# 2        Sharmistha Adhikari                     1.0                  1.0
# ...

# %%
#convert the datatypes to category format 
df2['UderstandingTopic(0-5)'] = df2['UderstandingTopic(0-5)'].astype("category")
df2['TrainingRating(0-5)'] = df2['TrainingRating(0-5)'].astype("category")
df2['Student_queries_sloved(0-5)'] = df2['Student_queries_sloved(0-5)'].astype("category")

# %%
df2.dtypes
# Out:
# Timestamp                          object
# Email                              object
# Name                               object
# UderstandingTopic(0-5)           category
# TrainingRating(0-5)              category
# Student_queries_sloved(0-5)      category
# want_join_full_time_courses        object
# recommend_course                   object
# want_apply_paid_intership          object
# suggestions_improving_program      object
# dtype: object

# %% [markdown]
# # Saving the datset after removing unnecessary things

# %%
df2.shape
# Out:
# (165, 10)

# %%
df2.to_csv('batch_inforamtion.csv')
